# %% [markdown]
# <a href="https://colab.research.google.com/github/andli28/HF-Deep-RL/blob/main/icra22_optuna_lab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Hyperparameter tuning with Optuna
#
# Github repo: https://github.com/araffin/tools-for-robotic-rl-icra2022
#
# Optuna: https://github.com/optuna/optuna
#
# Stable-Baselines3: https://github.com/DLR-RM/stable-baselines3
#
# Documentation: https://stable-baselines3.readthedocs.io/en/master/
#
# SB3 Contrib: https://github.com/Stable-Baselines-Team/stable-baselines3-contrib
#
# RL Baselines3 zoo: https://github.com/DLR-RM/rl-baselines3-zoo
#
# [RL Baselines3 Zoo](https://github.com/DLR-RM/rl-baselines3-zoo) is a collection of pre-trained Reinforcement Learning agents using Stable-Baselines3.
#
# It also provides basic scripts for training, evaluating agents, tuning hyperparameters and recording videos.
#
#
# ## Introduction
#
# In this notebook, you will learn the importance of tuning hyperparameters. You will first try to optimize the parameters manually and then we will see how to automate the search using Optuna.
#
#
# ## Install Dependencies and Stable Baselines3 Using Pip
#
# List of full dependencies can be found in the [README](https://github.com/DLR-RM/stable-baselines3).
#
#
# ```
# pip install stable-baselines3[extra]
# ```

# %%
# !pip install stable-baselines3
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting stable-baselines3
#   Downloading stable_baselines3-1.7.0-py3-none-any.whl (171 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 171.8/171.8 KB 16.6 MB/s eta 0:00:00
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.8/dist-packages (from stable-baselines3) (2.2.1)
# Requirement already satisfied: torch>=1.11 in /usr/local/lib/python3.8/dist-packages (from stable-baselines3) (1.13.1+cu116)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.8/dist-packages (from stable-baselines3) (3.5.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from stable-baselines3) (1.22.4)
# Collecting gym==0.21
#   Downloading gym-0.21.0.tar.gz (1.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 78.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pandas in /usr/local/lib/python3.8/dist-packages (from stable-baselines3) (1.3.5)
# Collecting importlib-metadata~=4.13
#   Downloading importlib_metadata-4.13.0-py3-none-any.whl (23 kB)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.8/dist-packages (from importlib-metadata~=4.13->stable-baselines3) (3.15.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.8/dist-packages (from torch>=1.11->stable-baselines3) (4.5.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.8/dist-packages (from matplotlib->stable-baselines3) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib->stable-baselines3) (8.4.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib->stable-baselines3) (23.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib->stable-baselines3) (4.38.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.8/dist-packages (from matplotlib->stable-baselines3) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib->stable-baselines3) (1.4.4)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib->stable-baselines3) (3.0.9)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas->stable-baselines3) (2022.7.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/dist-packages (from python-dateutil>=2.7->matplotlib->stable-baselines3) (1.15.0)
# Building wheels for collected packages: gym
#   Building wheel for gym (setup.py) ... done
#   Created wheel for gym: filename=gym-0.21.0-py3-none-any.whl size=1616825 sha256=9f8e5146f5af7a789d5a134abf1dd572638ad99bbd55791c586c6b73bef5fd88
#   Stored in directory: /root/.cache/pip/wheels/27/6d/b3/a3a6e10704795c9b9000f1ab2dc480dfe7bed42f5972806e73
# Successfully built gym
# Installing collected packages: importlib-metadata, gym, stable-baselines3
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib-metadata 6.0.0
#     Uninstalling importlib-metadata-6.0.0:
#       Successfully uninstalled importlib-metadata-6.0.0
#   Attempting uninstall: gym
#     Found existing installation: gym 0.25.2
#     Uninstalling gym-0.25.2:
#       Successfully uninstalled gym-0.25.2
# Successfully installed gym-0.21.0 importlib-metadata-4.13.0 stable-baselines3-1.7.0

# %%
# Optional: install SB3 contrib to have access to additional algorithms
# !pip install sb3-contrib
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting sb3-contrib
#   Downloading sb3_contrib-1.7.0-py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.1/79.1 KB 10.4 MB/s eta 0:00:00
# Requirement already satisfied: stable-baselines3>=1.7.0 in /usr/local/lib/python3.8/dist-packages (from sb3-contrib) (1.7.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.8/dist-packages (from stable-baselines3>=1.7.0->sb3-contrib) (3.5.3)
# Requirement already satisfied: importlib-metadata~=4.13 in /usr/local/lib/python3.8/dist-packages (from stable-baselines3>=1.7.0->sb3-contrib) (4.13.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.8/dist-packages (from stable-baselines3>=1.7.0->sb3-contrib) (1.3.5)
# Requirement already satisfied: torch>=1.11 in /usr/local/lib/python3.8/dist-packages (from stable-baselines3>=1.7.0->sb3-contrib) (1.13.1+cu116)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from stable-baselines3>=1.7.0->sb3-contrib) (1.22.4)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.8/dist-packages (from stable-baselines3>=1.7.0->sb3-contrib) (2.2.1)
# Requirement already satisfied: gym==0.21 in /usr/local/lib/python3.8/dist-packages (from stable-baselines3>=1.7.0->sb3-contrib) (0.21.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.8/dist-packages (from importlib-metadata~=4.13->stable-baselines3>=1.7.0->sb3-contrib) (3.15.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.8/dist-packages (from torch>=1.11->stable-baselines3>=1.7.0->sb3-contrib) (4.5.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.8/dist-packages (from matplotlib->stable-baselines3>=1.7.0->sb3-contrib) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib->stable-baselines3>=1.7.0->sb3-contrib) (1.4.4)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib->stable-baselines3>=1.7.0->sb3-contrib) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib->stable-baselines3>=1.7.0->sb3-contrib) (4.38.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib->stable-baselines3>=1.7.0->sb3-contrib) (8.4.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.8/dist-packages (from matplotlib->stable-baselines3>=1.7.0->sb3-contrib) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib->stable-baselines3>=1.7.0->sb3-contrib) (23.0)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas->stable-baselines3>=1.7.0->sb3-contrib) (2022.7.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/dist-packages (from python-dateutil>=2.7->matplotlib->stable-baselines3>=1.7.0->sb3-contrib) (1.15.0)
# Installing collected packages: sb3-contrib
# Successfully installed sb3-contrib-1.7.0

# %%
# Optuna will be used in the last part when doing hyperparameter tuning
# !pip install optuna
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting optuna
#   Downloading optuna-3.1.0-py3-none-any.whl (365 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 365.3/365.3 KB 23.6 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from optuna) (23.0)
# Collecting cmaes>=0.9.1
#   Downloading cmaes-0.9.1-py3-none-any.whl (21 kB)
# Collecting colorlog
#   Downloading colorlog-6.7.0-py2.py3-none-any.whl (11 kB)
# Collecting alembic>=1.5.0
#   Downloading alembic-1.9.4-py3-none-any.whl (210 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 210.5/210.5 KB 25.8 MB/s eta 0:00:00
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.8/dist-packages (from optuna) (6.0)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /usr/local/lib/python3.8/dist-packages (from optuna) (1.4.46)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (from optuna) (4.64.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from optuna) (1.22.4)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.8/dist-packages (from alembic>=1.5.0->optuna) (4.13.0)
# Collecting Mako
#   Downloading Mako-1.2.4-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.7/78.7 KB 10.7 MB/s eta 0:00:00
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.8/dist-packages (from alembic>=1.5.0->optuna) (5.12.0)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.8/dist-packages (from sqlalchemy>=1.3.0->optuna) (2.0.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.8/dist-packages (from importlib-metadata->alembic>=1.5.0->optuna) (3.15.0)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.8/dist-packages (from Mako->alembic>=1.5.0->optuna) (2.1.2)
# Installing collected packages: Mako, colorlog, cmaes, alembic, optuna
# Successfully installed Mako-1.2.4 alembic-1.9.4 cmaes-0.9.1 colorlog-6.7.0 optuna-3.1.0

# %% [markdown]
# ## Imports

# %%
import gym
import numpy as np

# %% [markdown]
# The first thing you need to import is the RL model, check the documentation to know what you can use on which problem

# %%
from stable_baselines3 import PPO, A2C, SAC, TD3, DQN

# %%
# Algorithms from the contrib repo
# https://github.com/Stable-Baselines-Team/stable-baselines3-contrib
from sb3_contrib import QRDQN, TQC

# %%
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.evaluation import evaluate_policy

# %% [markdown]
# # Part I: The Importance Of Tuned Hyperparameters

# %% [markdown]
# When compared with Supervised Learning, Deep Reinforcement Learning is far more sensitive to the choice of hyper-parameters such as learning rate, number of neurons, number of layers, optimizer ... etc.
#
# Poor choice of hyper-parameters can lead to poor/unstable convergence. This challenge is compounded by the variability in performance across random seeds (used to initialize the network weights and the environment).

# %% [markdown]
# In addition to hyperparameters, selecting the appropriate algorithm is also an important choice. We will demonstrate it on the simple Pendulum task.
#
# See [gym doc](https://gym.openai.com/envs/Pendulum-v0/): "The inverted pendulum swingup problem is a classic problem in the control literature. In this version  of the problem, the pendulum starts in a random position, and the goal is to swing it up so it stays upright."
#
#
# Let's try first with PPO and a small budget of 4000 steps (20 episodes):

# %%
env_id = "Pendulum-v1"
# Env used only for evaluation
eval_envs = make_vec_env(env_id, n_envs=10)
# 4000 training timesteps
budget_pendulum = 4000

# %% [markdown]
# ### PPO

# %%
ppo_model = PPO("MlpPolicy", env_id, seed=0, verbose=0).learn(budget_pendulum)

# %%
mean_reward, std_reward = evaluate_policy(ppo_model, eval_envs, n_eval_episodes=100, deterministic=True)

print(f"PPO Mean episode reward: {mean_reward:.2f} +/- {std_reward:.2f}")
# Out:
# PPO Mean episode reward: -1204.30 +/- 357.87

# %% [markdown]
# ### A2C

# %%
# Define and train a A2C model
a2c_model = A2C("MlpPolicy", env_id, seed=0, verbose=0).learn(budget_pendulum)

# %%
# Evaluate the train A2C model
mean_reward, std_reward = evaluate_policy(a2c_model, eval_envs, n_eval_episodes=100, deterministic=True)

print(f"A2C Mean episode reward: {mean_reward:.2f} +/- {std_reward:.2f}")
# Out:
# A2C Mean episode reward: -1222.83 +/- 130.82

# %% [markdown]
# Both are far from solving the env (mean reward around -200).
# Now, let's try with an off-policy algorithm:

# %% [markdown]
# ### Training longer PPO ?
#
# Maybe training longer would help?
#
# You can try with 10x the budget, but in the case of A2C/PPO, training longer won't help much, finding better hyperparameters is needed instead.

# %%
# train longer
new_budget = 10 * budget_pendulum

ppo_model = PPO("MlpPolicy", env_id, seed=0, verbose=0).learn(new_budget)

# %%
mean_reward, std_reward = evaluate_policy(ppo_model, eval_envs, n_eval_episodes=100, deterministic=True)

print(f"PPO Mean episode reward: {mean_reward:.2f} +/- {std_reward:.2f}")
# Out:
# PPO Mean episode reward: -1152.29 +/- 187.83

# %% [markdown]
# ### PPO - Tuned Hyperparameters
#
# Using Optuna, we can in fact tune the hyperparameters and find a working solution (from the [RL Zoo](https://github.com/DLR-RM/rl-baselines3-zoo/blob/master/hyperparams/ppo.yml)):

# %%
tuned_params = {
    "gamma": 0.9,
    "use_sde": True,
    "sde_sample_freq": 4,
    "learning_rate": 1e-3,
}

# budget = 10 * budget_pendulum
ppo_tuned_model = PPO("MlpPolicy", env_id, seed=1, verbose=1, **tuned_params).learn(50_000, log_interval=5)
# Out:
# Using cuda device
# Creating environment from the given name 'Pendulum-v1'
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 200        |
# |    ep_rew_mean          | -1.22e+03  |
# | time/                   |            |
# |    fps                  | 442        |
# |    iterations           | 5          |
# |    time_elapsed         | 23         |
# |    total_timesteps      | 10240      |
# | train/                  |            |
# |    approx_kl            | 0.02367109 |
# |    clip_fraction        | 0.266      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.74      |
# |    explained_variance   | 0.815      |
# |    learning_rate        | 0.001      |
# |    loss                 | 11.5       |
# |    n_updates            | 40         |
# |    policy_gradient_loss | -0.0281    |
# |    std                  | 0.961      |
# |    value_loss           | 35.5       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 200        |
# |    ep_rew_mean          | -1.1e+03   |
# | time/                   |            |
# |    fps                  | 433        |
# |    iterations           | 10         |
# |    time_elapsed         | 47         |
# |    total_timesteps      | 20480      |
# | train/                  |            |
# |    approx_kl            | 0.03547623 |
# |    clip_fraction        | 0.24       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.41      |
# |    explained_variance   | 0.957      |
# |    learning_rate        | 0.001      |
# |    loss                 | 5.36       |
# |    n_updates            | 90         |
# |    policy_gradient_loss | -0.0317    |
# |    std                  | 0.528      |
# |    value_loss           | 10.2       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 200        |
# |    ep_rew_mean          | -729       |
# | time/                   |            |
# |    fps                  | 429        |
# |    iterations           | 15         |
# |    time_elapsed         | 71         |
# |    total_timesteps      | 30720      |
# | train/                  |            |
# |    approx_kl            | 0.04057172 |
# |    clip_fraction        | 0.239      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.53      |
# |    explained_variance   | 0.992      |
# |    learning_rate        | 0.001      |
# |    loss                 | 1.01       |
# |    n_updates            | 140        |
# |    policy_gradient_loss | -0.0294    |
# |    std                  | 0.284      |
# |    value_loss           | 3.72       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -343        |
# | time/                   |             |
# |    fps                  | 425         |
# |    iterations           | 20          |
# |    time_elapsed         | 96          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.021096086 |
# |    clip_fraction        | 0.195       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.28       |
# |    explained_variance   | 0.998       |
# |    learning_rate        | 0.001       |
# |    loss                 | 0.284       |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00349    |
# |    std                  | 0.254       |
# |    value_loss           | 0.523       |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 200       |
# |    ep_rew_mean          | -186      |
# | time/                   |           |
# |    fps                  | 423       |
# |    iterations           | 25        |
# |    time_elapsed         | 120       |
# |    total_timesteps      | 51200     |
# | train/                  |           |
# |    approx_kl            | 0.0544203 |
# |    clip_fraction        | 0.242     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.01     |
# |    explained_variance   | 0.999     |
# |    learning_rate        | 0.001     |
# |    loss                 | 0.0217    |
# |    n_updates            | 240       |
# |    policy_gradient_loss | -0.0172   |
# |    std                  | 0.216     |
# |    value_loss           | 0.172     |
# ---------------------------------------

# %%
mean_reward, std_reward = evaluate_policy(ppo_tuned_model, eval_envs, n_eval_episodes=100, deterministic=True)

print(f"Tuned PPO Mean episode reward: {mean_reward:.2f} +/- {std_reward:.2f}")
# Out:
# Tuned PPO Mean episode reward: -194.41 +/- 109.28

# %% [markdown]
# Note: if you try SAC on the simple MountainCarContinuous environment, you will encounter some issues without tuned hyperparameters: https://github.com/rail-berkeley/softlearning/issues/76
#
# Simple environments can be challenging even for SOTA algorithms.

# %% [markdown]
# # Part II: Grad Student Descent

# %% [markdown]
# ### Challenge (10 minutes): "Grad Student Descent"
# The challenge is to find the best hyperparameters (max performance) for A2C on `CartPole-v1` with a limited budget of 20 000 training steps.
#
#
# Maximum reward: 500 on `CartPole-v1`
#
# The hyperparameters should work for different random seeds.

# %%
budget = 20_000

# %% [markdown]
# #### The baseline: default hyperparameters

# %%
eval_envs_cartpole = make_vec_env("CartPole-v1", n_envs=10)

# %%
model = A2C("MlpPolicy", "CartPole-v1", seed=8, verbose=1).learn(budget)
# Out:
# Using cuda device
# Creating environment from the given name 'CartPole-v1'
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 30       |
# |    ep_rew_mean        | 30       |
# | time/                 |          |
# |    fps                | 448      |
# |    iterations         | 100      |
# |    time_elapsed       | 1        |
# |    total_timesteps    | 500      |
# | train/                |          |
# |    entropy_loss       | -0.685   |
# |    explained_variance | -0.408   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 99       |
# |    policy_loss        | 2.03     |
# |    value_loss         | 12.9     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 35.8     |
# |    ep_rew_mean        | 35.8     |
# | time/                 |          |
# |    fps                | 450      |
# |    iterations         | 200      |
# |    time_elapsed       | 2        |
# |    total_timesteps    | 1000     |
# | train/                |          |
# |    entropy_loss       | -0.685   |
# |    explained_variance | 0.368    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 199      |
# |    policy_loss        | 1.11     |
# |    value_loss         | 3.68     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 42       |
# |    ep_rew_mean        | 42       |
# | time/                 |          |
# |    fps                | 448      |
# |    iterations         | 300      |
# |    time_elapsed       | 3        |
# |    total_timesteps    | 1500     |
# | train/                |          |
# |    entropy_loss       | -0.667   |
# |    explained_variance | 0.231    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 299      |
# |    policy_loss        | 1.22     |
# |    value_loss         | 4.06     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 41.4     |
# |    ep_rew_mean        | 41.4     |
# | time/                 |          |
# |    fps                | 451      |
# |    iterations         | 400      |
# |    time_elapsed       | 4        |
# |    total_timesteps    | 2000     |
# | train/                |          |
# |    entropy_loss       | -0.587   |
# |    explained_variance | 0.0697   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 399      |
# |    policy_loss        | 2        |
# |    value_loss         | 4.93     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 40.7     |
# |    ep_rew_mean        | 40.7     |
# | time/                 |          |
# |    fps                | 451      |
# |    iterations         | 500      |
# |    time_elapsed       | 5        |
# |    total_timesteps    | 2500     |
# | train/                |          |
# |    entropy_loss       | -0.644   |
# |    explained_variance | 0.0352   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 499      |
# |    policy_loss        | 0.865    |
# |    value_loss         | 4.99     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 40       |
# |    ep_rew_mean        | 40       |
# | time/                 |          |
# |    fps                | 454      |
# |    iterations         | 600      |
# |    time_elapsed       | 6        |
# |    total_timesteps    | 3000     |
# | train/                |          |
# |    entropy_loss       | -0.654   |
# |    explained_variance | -0.0138  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 599      |
# |    policy_loss        | 1.04     |
# |    value_loss         | 4.67     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 42.2     |
# |    ep_rew_mean        | 42.2     |
# | time/                 |          |
# |    fps                | 454      |
# |    iterations         | 700      |
# |    time_elapsed       | 7        |
# |    total_timesteps    | 3500     |
# | train/                |          |
# |    entropy_loss       | -0.558   |
# |    explained_variance | -0.0202  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 699      |
# |    policy_loss        | 1.35     |
# |    value_loss         | 4.15     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 43.2     |
# |    ep_rew_mean        | 43.2     |
# | time/                 |          |
# |    fps                | 442      |
# |    iterations         | 800      |
# |    time_elapsed       | 9        |
# |    total_timesteps    | 4000     |
# | train/                |          |
# |    entropy_loss       | -0.622   |
# |    explained_variance | 0.0103   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 799      |
# |    policy_loss        | 1.19     |
# |    value_loss         | 3.6      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 44.1     |
# |    ep_rew_mean        | 44.1     |
# | time/                 |          |
# |    fps                | 428      |
# |    iterations         | 900      |
# |    time_elapsed       | 10       |
# |    total_timesteps    | 4500     |
# | train/                |          |
# |    entropy_loss       | -0.511   |
# |    explained_variance | 0.000999 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 899      |
# |    policy_loss        | 1.08     |
# |    value_loss         | 3.2      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 46.3     |
# |    ep_rew_mean        | 46.3     |
# | time/                 |          |
# |    fps                | 427      |
# |    iterations         | 1000     |
# |    time_elapsed       | 11       |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -0.583   |
# |    explained_variance | -0.00338 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 999      |
# |    policy_loss        | 0.942    |
# |    value_loss         | 2.81     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 47.9     |
# |    ep_rew_mean        | 47.9     |
# | time/                 |          |
# |    fps                | 429      |
# |    iterations         | 1100     |
# |    time_elapsed       | 12       |
# |    total_timesteps    | 5500     |
# | train/                |          |
# |    entropy_loss       | -0.638   |
# |    explained_variance | 0.000662 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1099     |
# |    policy_loss        | 0.782    |
# |    value_loss         | 2.39     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 49.4     |
# |    ep_rew_mean        | 49.4     |
# | time/                 |          |
# |    fps                | 431      |
# |    iterations         | 1200     |
# |    time_elapsed       | 13       |
# |    total_timesteps    | 6000     |
# | train/                |          |
# |    entropy_loss       | -0.623   |
# |    explained_variance | 0.00194  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1199     |
# |    policy_loss        | 0.613    |
# |    value_loss         | 2.02     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 49.2     |
# |    ep_rew_mean        | 49.2     |
# | time/                 |          |
# |    fps                | 433      |
# |    iterations         | 1300     |
# |    time_elapsed       | 15       |
# |    total_timesteps    | 6500     |
# | train/                |          |
# |    entropy_loss       | -0.647   |
# |    explained_variance | 0.000466 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1299     |
# |    policy_loss        | 0.659    |
# |    value_loss         | 1.7      |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 50.9      |
# |    ep_rew_mean        | 50.9      |
# | time/                 |           |
# |    fps                | 434       |
# |    iterations         | 1400      |
# |    time_elapsed       | 16        |
# |    total_timesteps    | 7000      |
# | train/                |           |
# |    entropy_loss       | -0.642    |
# |    explained_variance | -4.65e-06 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1399      |
# |    policy_loss        | 0.583     |
# |    value_loss         | 1.35      |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 54.9     |
# |    ep_rew_mean        | 54.9     |
# | time/                 |          |
# |    fps                | 435      |
# |    iterations         | 1500     |
# |    time_elapsed       | 17       |
# |    total_timesteps    | 7500     |
# | train/                |          |
# |    entropy_loss       | -0.586   |
# |    explained_variance | 5.14e-05 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1499     |
# |    policy_loss        | 0.452    |
# |    value_loss         | 1.03     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 61.3     |
# |    ep_rew_mean        | 61.3     |
# | time/                 |          |
# |    fps                | 437      |
# |    iterations         | 1600     |
# |    time_elapsed       | 18       |
# |    total_timesteps    | 8000     |
# | train/                |          |
# |    entropy_loss       | -0.45    |
# |    explained_variance | 5.29e-05 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1599     |
# |    policy_loss        | -30      |
# |    value_loss         | 3.06e+03 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 65.1     |
# |    ep_rew_mean        | 65.1     |
# | time/                 |          |
# |    fps                | 438      |
# |    iterations         | 1700     |
# |    time_elapsed       | 19       |
# |    total_timesteps    | 8500     |
# | train/                |          |
# |    entropy_loss       | -0.571   |
# |    explained_variance | -7e-05   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1699     |
# |    policy_loss        | 0.364    |
# |    value_loss         | 0.533    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 68.5     |
# |    ep_rew_mean        | 68.5     |
# | time/                 |          |
# |    fps                | 439      |
# |    iterations         | 1800     |
# |    time_elapsed       | 20       |
# |    total_timesteps    | 9000     |
# | train/                |          |
# |    entropy_loss       | -0.509   |
# |    explained_variance | 0.000104 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1799     |
# |    policy_loss        | 0.45     |
# |    value_loss         | 0.345    |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 72.7      |
# |    ep_rew_mean        | 72.7      |
# | time/                 |           |
# |    fps                | 436       |
# |    iterations         | 1900      |
# |    time_elapsed       | 21        |
# |    total_timesteps    | 9500      |
# | train/                |           |
# |    entropy_loss       | -0.59     |
# |    explained_variance | -0.000113 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1899      |
# |    policy_loss        | 0.19      |
# |    value_loss         | 0.198     |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 77.3      |
# |    ep_rew_mean        | 77.3      |
# | time/                 |           |
# |    fps                | 429       |
# |    iterations         | 2000      |
# |    time_elapsed       | 23        |
# |    total_timesteps    | 10000     |
# | train/                |           |
# |    entropy_loss       | -0.588    |
# |    explained_variance | -1.69e-05 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1999      |
# |    policy_loss        | 0.157     |
# |    value_loss         | 0.0932    |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 80.1      |
# |    ep_rew_mean        | 80.1      |
# | time/                 |           |
# |    fps                | 429       |
# |    iterations         | 2100      |
# |    time_elapsed       | 24        |
# |    total_timesteps    | 10500     |
# | train/                |           |
# |    entropy_loss       | -0.57     |
# |    explained_variance | -6.18e-05 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2099      |
# |    policy_loss        | 0.0575    |
# |    value_loss         | 0.0264    |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 85.4     |
# |    ep_rew_mean        | 85.4     |
# | time/                 |          |
# |    fps                | 431      |
# |    iterations         | 2200     |
# |    time_elapsed       | 25       |
# |    total_timesteps    | 11000    |
# | train/                |          |
# |    entropy_loss       | -0.629   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2199     |
# |    policy_loss        | 0.0146   |
# |    value_loss         | 0.00107  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 89.3     |
# |    ep_rew_mean        | 89.3     |
# | time/                 |          |
# |    fps                | 432      |
# |    iterations         | 2300     |
# |    time_elapsed       | 26       |
# |    total_timesteps    | 11500    |
# | train/                |          |
# |    entropy_loss       | -0.582   |
# |    explained_variance | 0.00139  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2299     |
# |    policy_loss        | 0.00191  |
# |    value_loss         | 1.36e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 93.7     |
# |    ep_rew_mean        | 93.7     |
# | time/                 |          |
# |    fps                | 433      |
# |    iterations         | 2400     |
# |    time_elapsed       | 27       |
# |    total_timesteps    | 12000    |
# | train/                |          |
# |    entropy_loss       | -0.662   |
# |    explained_variance | -0.00947 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2399     |
# |    policy_loss        | 0.000469 |
# |    value_loss         | 1.16e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 97.4     |
# |    ep_rew_mean        | 97.4     |
# | time/                 |          |
# |    fps                | 434      |
# |    iterations         | 2500     |
# |    time_elapsed       | 28       |
# |    total_timesteps    | 12500    |
# | train/                |          |
# |    entropy_loss       | -0.618   |
# |    explained_variance | 0.0718   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2499     |
# |    policy_loss        | 0.000114 |
# |    value_loss         | 1.1e-07  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 101      |
# |    ep_rew_mean        | 101      |
# | time/                 |          |
# |    fps                | 436      |
# |    iterations         | 2600     |
# |    time_elapsed       | 29       |
# |    total_timesteps    | 13000    |
# | train/                |          |
# |    entropy_loss       | -0.658   |
# |    explained_variance | -0.12    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2599     |
# |    policy_loss        | 1.78e-05 |
# |    value_loss         | 1.26e-09 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 106      |
# |    ep_rew_mean        | 106      |
# | time/                 |          |
# |    fps                | 437      |
# |    iterations         | 2700     |
# |    time_elapsed       | 30       |
# |    total_timesteps    | 13500    |
# | train/                |          |
# |    entropy_loss       | -0.398   |
# |    explained_variance | 0.0644   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2699     |
# |    policy_loss        | 0.000496 |
# |    value_loss         | 2.31e-07 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 109      |
# |    ep_rew_mean        | 109      |
# | time/                 |          |
# |    fps                | 438      |
# |    iterations         | 2800     |
# |    time_elapsed       | 31       |
# |    total_timesteps    | 14000    |
# | train/                |          |
# |    entropy_loss       | -0.586   |
# |    explained_variance | 0.00248  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2799     |
# |    policy_loss        | 0.00218  |
# |    value_loss         | 1.65e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 112      |
# |    ep_rew_mean        | 112      |
# | time/                 |          |
# |    fps                | 438      |
# |    iterations         | 2900     |
# |    time_elapsed       | 33       |
# |    total_timesteps    | 14500    |
# | train/                |          |
# |    entropy_loss       | -0.531   |
# |    explained_variance | 0.0221   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2899     |
# |    policy_loss        | 0.000366 |
# |    value_loss         | 1.88e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 116      |
# |    ep_rew_mean        | 116      |
# | time/                 |          |
# |    fps                | 436      |
# |    iterations         | 3000     |
# |    time_elapsed       | 34       |
# |    total_timesteps    | 15000    |
# | train/                |          |
# |    entropy_loss       | -0.637   |
# |    explained_variance | 7.69e-06 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2999     |
# |    policy_loss        | 0.000557 |
# |    value_loss         | 1.64e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 119      |
# |    ep_rew_mean        | 119      |
# | time/                 |          |
# |    fps                | 432      |
# |    iterations         | 3100     |
# |    time_elapsed       | 35       |
# |    total_timesteps    | 15500    |
# | train/                |          |
# |    entropy_loss       | -0.543   |
# |    explained_variance | -0.0624  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3099     |
# |    policy_loss        | 5.55e-05 |
# |    value_loss         | 2.21e-08 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 121       |
# |    ep_rew_mean        | 121       |
# | time/                 |           |
# |    fps                | 432       |
# |    iterations         | 3200      |
# |    time_elapsed       | 37        |
# |    total_timesteps    | 16000     |
# | train/                |           |
# |    entropy_loss       | -0.29     |
# |    explained_variance | nan       |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3199      |
# |    policy_loss        | -2.16e-05 |
# |    value_loss         | 2.91e-10  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 127      |
# |    ep_rew_mean        | 127      |
# | time/                 |          |
# |    fps                | 432      |
# |    iterations         | 3300     |
# |    time_elapsed       | 38       |
# |    total_timesteps    | 16500    |
# | train/                |          |
# |    entropy_loss       | -0.569   |
# |    explained_variance | 0.0474   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3299     |
# |    policy_loss        | 0.000157 |
# |    value_loss         | 1.82e-07 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 131      |
# |    ep_rew_mean        | 131      |
# | time/                 |          |
# |    fps                | 433      |
# |    iterations         | 3400     |
# |    time_elapsed       | 39       |
# |    total_timesteps    | 17000    |
# | train/                |          |
# |    entropy_loss       | -0.453   |
# |    explained_variance | 3.7e-06  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3399     |
# |    policy_loss        | 0.00561  |
# |    value_loss         | 6.58e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 133      |
# |    ep_rew_mean        | 133      |
# | time/                 |          |
# |    fps                | 434      |
# |    iterations         | 3500     |
# |    time_elapsed       | 40       |
# |    total_timesteps    | 17500    |
# | train/                |          |
# |    entropy_loss       | -0.558   |
# |    explained_variance | -0.0701  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3499     |
# |    policy_loss        | 0.000135 |
# |    value_loss         | 9.93e-08 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 139      |
# |    ep_rew_mean        | 139      |
# | time/                 |          |
# |    fps                | 434      |
# |    iterations         | 3600     |
# |    time_elapsed       | 41       |
# |    total_timesteps    | 18000    |
# | train/                |          |
# |    entropy_loss       | -0.544   |
# |    explained_variance | 1.19e-07 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3599     |
# |    policy_loss        | -26.3    |
# |    value_loss         | 5.76e+03 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 140      |
# |    ep_rew_mean        | 140      |
# | time/                 |          |
# |    fps                | 434      |
# |    iterations         | 3700     |
# |    time_elapsed       | 42       |
# |    total_timesteps    | 18500    |
# | train/                |          |
# |    entropy_loss       | -0.596   |
# |    explained_variance | -3.93    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3699     |
# |    policy_loss        | 2.1e-05  |
# |    value_loss         | 2.6e-09  |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 144       |
# |    ep_rew_mean        | 144       |
# | time/                 |           |
# |    fps                | 435       |
# |    iterations         | 3800      |
# |    time_elapsed       | 43        |
# |    total_timesteps    | 19000     |
# | train/                |           |
# |    entropy_loss       | -0.634    |
# |    explained_variance | -1.78     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3799      |
# |    policy_loss        | -4.66e-05 |
# |    value_loss         | 1.47e-07  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 148      |
# |    ep_rew_mean        | 148      |
# | time/                 |          |
# |    fps                | 436      |
# |    iterations         | 3900     |
# |    time_elapsed       | 44       |
# |    total_timesteps    | 19500    |
# | train/                |          |
# |    entropy_loss       | -0.563   |
# |    explained_variance | 0.0532   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3899     |
# |    policy_loss        | 0.00276  |
# |    value_loss         | 3.17e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 150      |
# |    ep_rew_mean        | 150      |
# | time/                 |          |
# |    fps                | 436      |
# |    iterations         | 4000     |
# |    time_elapsed       | 45       |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -0.648   |
# |    explained_variance | -0.00458 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3999     |
# |    policy_loss        | 0.00671  |
# |    value_loss         | 0.000248 |
# ------------------------------------

# %%
mean_reward, std_reward = evaluate_policy(model, eval_envs_cartpole, n_eval_episodes=50, deterministic=True)

print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")
# Out:
# mean_reward:138.52 +/- 48.89

# %% [markdown]
# **Your goal is to beat that baseline and get closer to the optimal score of 500**

# %% [markdown]
# Time to tune!

# %%
import torch.nn as nn

# %%
policy_kwargs = dict(
    net_arch=[
      dict(vf=[64, 64], pi=[64, 64]), # network architectures for actor/critic
    ],
    activation_fn=nn.Tanh,
)

hyperparams = dict(
    n_steps=5, # number of steps to collect data before updating policy
    learning_rate=7e-4,
    gamma=0.99, # discount factor
    max_grad_norm=0.5, # The maximum value for the gradient clipping
    ent_coef=0.0, # Entropy coefficient for the loss calculation
)

model = A2C("MlpPolicy", "CartPole-v1", seed=8, verbose=1, **hyperparams).learn(budget)
# Out:
# Using cuda device
# Creating environment from the given name 'CartPole-v1'
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 30       |
# |    ep_rew_mean        | 30       |
# | time/                 |          |
# |    fps                | 477      |
# |    iterations         | 100      |
# |    time_elapsed       | 1        |
# |    total_timesteps    | 500      |
# | train/                |          |
# |    entropy_loss       | -0.685   |
# |    explained_variance | -0.408   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 99       |
# |    policy_loss        | 2.03     |
# |    value_loss         | 12.9     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 35.8     |
# |    ep_rew_mean        | 35.8     |
# | time/                 |          |
# |    fps                | 471      |
# |    iterations         | 200      |
# |    time_elapsed       | 2        |
# |    total_timesteps    | 1000     |
# | train/                |          |
# |    entropy_loss       | -0.685   |
# |    explained_variance | 0.368    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 199      |
# |    policy_loss        | 1.11     |
# |    value_loss         | 3.68     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 42       |
# |    ep_rew_mean        | 42       |
# | time/                 |          |
# |    fps                | 467      |
# |    iterations         | 300      |
# |    time_elapsed       | 3        |
# |    total_timesteps    | 1500     |
# | train/                |          |
# |    entropy_loss       | -0.667   |
# |    explained_variance | 0.231    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 299      |
# |    policy_loss        | 1.22     |
# |    value_loss         | 4.06     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 41.4     |
# |    ep_rew_mean        | 41.4     |
# | time/                 |          |
# |    fps                | 461      |
# |    iterations         | 400      |
# |    time_elapsed       | 4        |
# |    total_timesteps    | 2000     |
# | train/                |          |
# |    entropy_loss       | -0.587   |
# |    explained_variance | 0.0697   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 399      |
# |    policy_loss        | 2        |
# |    value_loss         | 4.93     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 40.7     |
# |    ep_rew_mean        | 40.7     |
# | time/                 |          |
# |    fps                | 459      |
# |    iterations         | 500      |
# |    time_elapsed       | 5        |
# |    total_timesteps    | 2500     |
# | train/                |          |
# |    entropy_loss       | -0.644   |
# |    explained_variance | 0.0352   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 499      |
# |    policy_loss        | 0.865    |
# |    value_loss         | 4.99     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 40       |
# |    ep_rew_mean        | 40       |
# | time/                 |          |
# |    fps                | 445      |
# |    iterations         | 600      |
# |    time_elapsed       | 6        |
# |    total_timesteps    | 3000     |
# | train/                |          |
# |    entropy_loss       | -0.654   |
# |    explained_variance | -0.0138  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 599      |
# |    policy_loss        | 1.04     |
# |    value_loss         | 4.67     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 42.2     |
# |    ep_rew_mean        | 42.2     |
# | time/                 |          |
# |    fps                | 426      |
# |    iterations         | 700      |
# |    time_elapsed       | 8        |
# |    total_timesteps    | 3500     |
# | train/                |          |
# |    entropy_loss       | -0.558   |
# |    explained_variance | -0.0202  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 699      |
# |    policy_loss        | 1.35     |
# |    value_loss         | 4.15     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 43.2     |
# |    ep_rew_mean        | 43.2     |
# | time/                 |          |
# |    fps                | 423      |
# |    iterations         | 800      |
# |    time_elapsed       | 9        |
# |    total_timesteps    | 4000     |
# | train/                |          |
# |    entropy_loss       | -0.622   |
# |    explained_variance | 0.0103   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 799      |
# |    policy_loss        | 1.19     |
# |    value_loss         | 3.6      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 44.1     |
# |    ep_rew_mean        | 44.1     |
# | time/                 |          |
# |    fps                | 428      |
# |    iterations         | 900      |
# |    time_elapsed       | 10       |
# |    total_timesteps    | 4500     |
# | train/                |          |
# |    entropy_loss       | -0.511   |
# |    explained_variance | 0.000999 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 899      |
# |    policy_loss        | 1.08     |
# |    value_loss         | 3.2      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 46.3     |
# |    ep_rew_mean        | 46.3     |
# | time/                 |          |
# |    fps                | 430      |
# |    iterations         | 1000     |
# |    time_elapsed       | 11       |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -0.583   |
# |    explained_variance | -0.00338 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 999      |
# |    policy_loss        | 0.942    |
# |    value_loss         | 2.81     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 47.9     |
# |    ep_rew_mean        | 47.9     |
# | time/                 |          |
# |    fps                | 430      |
# |    iterations         | 1100     |
# |    time_elapsed       | 12       |
# |    total_timesteps    | 5500     |
# | train/                |          |
# |    entropy_loss       | -0.638   |
# |    explained_variance | 0.000662 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1099     |
# |    policy_loss        | 0.782    |
# |    value_loss         | 2.39     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 49.4     |
# |    ep_rew_mean        | 49.4     |
# | time/                 |          |
# |    fps                | 432      |
# |    iterations         | 1200     |
# |    time_elapsed       | 13       |
# |    total_timesteps    | 6000     |
# | train/                |          |
# |    entropy_loss       | -0.623   |
# |    explained_variance | 0.00194  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1199     |
# |    policy_loss        | 0.613    |
# |    value_loss         | 2.02     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 49.2     |
# |    ep_rew_mean        | 49.2     |
# | time/                 |          |
# |    fps                | 433      |
# |    iterations         | 1300     |
# |    time_elapsed       | 14       |
# |    total_timesteps    | 6500     |
# | train/                |          |
# |    entropy_loss       | -0.647   |
# |    explained_variance | 0.000466 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1299     |
# |    policy_loss        | 0.659    |
# |    value_loss         | 1.7      |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 50.9      |
# |    ep_rew_mean        | 50.9      |
# | time/                 |           |
# |    fps                | 435       |
# |    iterations         | 1400      |
# |    time_elapsed       | 16        |
# |    total_timesteps    | 7000      |
# | train/                |           |
# |    entropy_loss       | -0.642    |
# |    explained_variance | -4.65e-06 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1399      |
# |    policy_loss        | 0.583     |
# |    value_loss         | 1.35      |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 54.9     |
# |    ep_rew_mean        | 54.9     |
# | time/                 |          |
# |    fps                | 436      |
# |    iterations         | 1500     |
# |    time_elapsed       | 17       |
# |    total_timesteps    | 7500     |
# | train/                |          |
# |    entropy_loss       | -0.586   |
# |    explained_variance | 5.14e-05 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1499     |
# |    policy_loss        | 0.452    |
# |    value_loss         | 1.03     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 61.3     |
# |    ep_rew_mean        | 61.3     |
# | time/                 |          |
# |    fps                | 436      |
# |    iterations         | 1600     |
# |    time_elapsed       | 18       |
# |    total_timesteps    | 8000     |
# | train/                |          |
# |    entropy_loss       | -0.45    |
# |    explained_variance | 5.29e-05 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1599     |
# |    policy_loss        | -30      |
# |    value_loss         | 3.06e+03 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 65.1     |
# |    ep_rew_mean        | 65.1     |
# | time/                 |          |
# |    fps                | 432      |
# |    iterations         | 1700     |
# |    time_elapsed       | 19       |
# |    total_timesteps    | 8500     |
# | train/                |          |
# |    entropy_loss       | -0.571   |
# |    explained_variance | -7e-05   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1699     |
# |    policy_loss        | 0.364    |
# |    value_loss         | 0.533    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 68.5     |
# |    ep_rew_mean        | 68.5     |
# | time/                 |          |
# |    fps                | 424      |
# |    iterations         | 1800     |
# |    time_elapsed       | 21       |
# |    total_timesteps    | 9000     |
# | train/                |          |
# |    entropy_loss       | -0.509   |
# |    explained_variance | 0.000104 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1799     |
# |    policy_loss        | 0.45     |
# |    value_loss         | 0.345    |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 72.7      |
# |    ep_rew_mean        | 72.7      |
# | time/                 |           |
# |    fps                | 423       |
# |    iterations         | 1900      |
# |    time_elapsed       | 22        |
# |    total_timesteps    | 9500      |
# | train/                |           |
# |    entropy_loss       | -0.59     |
# |    explained_variance | -0.000113 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1899      |
# |    policy_loss        | 0.19      |
# |    value_loss         | 0.198     |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 77.3      |
# |    ep_rew_mean        | 77.3      |
# | time/                 |           |
# |    fps                | 424       |
# |    iterations         | 2000      |
# |    time_elapsed       | 23        |
# |    total_timesteps    | 10000     |
# | train/                |           |
# |    entropy_loss       | -0.588    |
# |    explained_variance | -1.69e-05 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1999      |
# |    policy_loss        | 0.157     |
# |    value_loss         | 0.0932    |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 80.1      |
# |    ep_rew_mean        | 80.1      |
# | time/                 |           |
# |    fps                | 425       |
# |    iterations         | 2100      |
# |    time_elapsed       | 24        |
# |    total_timesteps    | 10500     |
# | train/                |           |
# |    entropy_loss       | -0.57     |
# |    explained_variance | -6.18e-05 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2099      |
# |    policy_loss        | 0.0575    |
# |    value_loss         | 0.0264    |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 85.4     |
# |    ep_rew_mean        | 85.4     |
# | time/                 |          |
# |    fps                | 425      |
# |    iterations         | 2200     |
# |    time_elapsed       | 25       |
# |    total_timesteps    | 11000    |
# | train/                |          |
# |    entropy_loss       | -0.629   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2199     |
# |    policy_loss        | 0.0146   |
# |    value_loss         | 0.00107  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 89.3     |
# |    ep_rew_mean        | 89.3     |
# | time/                 |          |
# |    fps                | 426      |
# |    iterations         | 2300     |
# |    time_elapsed       | 26       |
# |    total_timesteps    | 11500    |
# | train/                |          |
# |    entropy_loss       | -0.582   |
# |    explained_variance | 0.00139  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2299     |
# |    policy_loss        | 0.00191  |
# |    value_loss         | 1.36e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 93.7     |
# |    ep_rew_mean        | 93.7     |
# | time/                 |          |
# |    fps                | 428      |
# |    iterations         | 2400     |
# |    time_elapsed       | 28       |
# |    total_timesteps    | 12000    |
# | train/                |          |
# |    entropy_loss       | -0.662   |
# |    explained_variance | -0.00947 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2399     |
# |    policy_loss        | 0.000469 |
# |    value_loss         | 1.16e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 97.4     |
# |    ep_rew_mean        | 97.4     |
# | time/                 |          |
# |    fps                | 429      |
# |    iterations         | 2500     |
# |    time_elapsed       | 29       |
# |    total_timesteps    | 12500    |
# | train/                |          |
# |    entropy_loss       | -0.618   |
# |    explained_variance | 0.0718   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2499     |
# |    policy_loss        | 0.000114 |
# |    value_loss         | 1.1e-07  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 101      |
# |    ep_rew_mean        | 101      |
# | time/                 |          |
# |    fps                | 429      |
# |    iterations         | 2600     |
# |    time_elapsed       | 30       |
# |    total_timesteps    | 13000    |
# | train/                |          |
# |    entropy_loss       | -0.658   |
# |    explained_variance | -0.12    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2599     |
# |    policy_loss        | 1.78e-05 |
# |    value_loss         | 1.26e-09 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 106      |
# |    ep_rew_mean        | 106      |
# | time/                 |          |
# |    fps                | 430      |
# |    iterations         | 2700     |
# |    time_elapsed       | 31       |
# |    total_timesteps    | 13500    |
# | train/                |          |
# |    entropy_loss       | -0.398   |
# |    explained_variance | 0.0644   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2699     |
# |    policy_loss        | 0.000496 |
# |    value_loss         | 2.31e-07 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 109      |
# |    ep_rew_mean        | 109      |
# | time/                 |          |
# |    fps                | 424      |
# |    iterations         | 2800     |
# |    time_elapsed       | 32       |
# |    total_timesteps    | 14000    |
# | train/                |          |
# |    entropy_loss       | -0.586   |
# |    explained_variance | 0.00248  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2799     |
# |    policy_loss        | 0.00218  |
# |    value_loss         | 1.65e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 112      |
# |    ep_rew_mean        | 112      |
# | time/                 |          |
# |    fps                | 420      |
# |    iterations         | 2900     |
# |    time_elapsed       | 34       |
# |    total_timesteps    | 14500    |
# | train/                |          |
# |    entropy_loss       | -0.531   |
# |    explained_variance | 0.0221   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2899     |
# |    policy_loss        | 0.000366 |
# |    value_loss         | 1.88e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 116      |
# |    ep_rew_mean        | 116      |
# | time/                 |          |
# |    fps                | 419      |
# |    iterations         | 3000     |
# |    time_elapsed       | 35       |
# |    total_timesteps    | 15000    |
# | train/                |          |
# |    entropy_loss       | -0.637   |
# |    explained_variance | 7.69e-06 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2999     |
# |    policy_loss        | 0.000557 |
# |    value_loss         | 1.64e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 119      |
# |    ep_rew_mean        | 119      |
# | time/                 |          |
# |    fps                | 419      |
# |    iterations         | 3100     |
# |    time_elapsed       | 36       |
# |    total_timesteps    | 15500    |
# | train/                |          |
# |    entropy_loss       | -0.543   |
# |    explained_variance | -0.0624  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3099     |
# |    policy_loss        | 5.55e-05 |
# |    value_loss         | 2.21e-08 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 121       |
# |    ep_rew_mean        | 121       |
# | time/                 |           |
# |    fps                | 420       |
# |    iterations         | 3200      |
# |    time_elapsed       | 38        |
# |    total_timesteps    | 16000     |
# | train/                |           |
# |    entropy_loss       | -0.29     |
# |    explained_variance | nan       |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3199      |
# |    policy_loss        | -2.16e-05 |
# |    value_loss         | 2.91e-10  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 127      |
# |    ep_rew_mean        | 127      |
# | time/                 |          |
# |    fps                | 421      |
# |    iterations         | 3300     |
# |    time_elapsed       | 39       |
# |    total_timesteps    | 16500    |
# | train/                |          |
# |    entropy_loss       | -0.569   |
# |    explained_variance | 0.0474   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3299     |
# |    policy_loss        | 0.000157 |
# |    value_loss         | 1.82e-07 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 131      |
# |    ep_rew_mean        | 131      |
# | time/                 |          |
# |    fps                | 421      |
# |    iterations         | 3400     |
# |    time_elapsed       | 40       |
# |    total_timesteps    | 17000    |
# | train/                |          |
# |    entropy_loss       | -0.453   |
# |    explained_variance | 3.7e-06  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3399     |
# |    policy_loss        | 0.00561  |
# |    value_loss         | 6.58e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 133      |
# |    ep_rew_mean        | 133      |
# | time/                 |          |
# |    fps                | 422      |
# |    iterations         | 3500     |
# |    time_elapsed       | 41       |
# |    total_timesteps    | 17500    |
# | train/                |          |
# |    entropy_loss       | -0.558   |
# |    explained_variance | -0.0701  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3499     |
# |    policy_loss        | 0.000135 |
# |    value_loss         | 9.93e-08 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 139      |
# |    ep_rew_mean        | 139      |
# | time/                 |          |
# |    fps                | 422      |
# |    iterations         | 3600     |
# |    time_elapsed       | 42       |
# |    total_timesteps    | 18000    |
# | train/                |          |
# |    entropy_loss       | -0.544   |
# |    explained_variance | 1.19e-07 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3599     |
# |    policy_loss        | -26.3    |
# |    value_loss         | 5.76e+03 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 140      |
# |    ep_rew_mean        | 140      |
# | time/                 |          |
# |    fps                | 423      |
# |    iterations         | 3700     |
# |    time_elapsed       | 43       |
# |    total_timesteps    | 18500    |
# | train/                |          |
# |    entropy_loss       | -0.596   |
# |    explained_variance | -3.93    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3699     |
# |    policy_loss        | 2.1e-05  |
# |    value_loss         | 2.6e-09  |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 144       |
# |    ep_rew_mean        | 144       |
# | time/                 |           |
# |    fps                | 422       |
# |    iterations         | 3800      |
# |    time_elapsed       | 44        |
# |    total_timesteps    | 19000     |
# | train/                |           |
# |    entropy_loss       | -0.634    |
# |    explained_variance | -1.78     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3799      |
# |    policy_loss        | -4.66e-05 |
# |    value_loss         | 1.47e-07  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 148      |
# |    ep_rew_mean        | 148      |
# | time/                 |          |
# |    fps                | 419      |
# |    iterations         | 3900     |
# |    time_elapsed       | 46       |
# |    total_timesteps    | 19500    |
# | train/                |          |
# |    entropy_loss       | -0.563   |
# |    explained_variance | 0.0532   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3899     |
# |    policy_loss        | 0.00276  |
# |    value_loss         | 3.17e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 150      |
# |    ep_rew_mean        | 150      |
# | time/                 |          |
# |    fps                | 418      |
# |    iterations         | 4000     |
# |    time_elapsed       | 47       |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -0.648   |
# |    explained_variance | -0.00458 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3999     |
# |    policy_loss        | 0.00671  |
# |    value_loss         | 0.000248 |
# ------------------------------------

# %%
mean_reward, std_reward = evaluate_policy(model, eval_envs_cartpole, n_eval_episodes=50, deterministic=True)

print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")
# Out:
# mean_reward:138.04 +/- 64.65

# %% [markdown]
# Hint - Recommended Hyperparameter Range
#
# ```python
# gamma = trial.suggest_float("gamma", 0.9, 0.99999, log=True)
# max_grad_norm = trial.suggest_float("max_grad_norm", 0.3, 5.0, log=True)
# # from 2**3 = 8 to 2**10 = 1024
# n_steps = 2 ** trial.suggest_int("exponent_n_steps", 3, 10)
# learning_rate = trial.suggest_float("lr", 1e-5, 1, log=True)
# ent_coef = trial.suggest_float("ent_coef", 0.00000001, 0.1, log=True)
# # net_arch tiny: {"pi": [64], "vf": [64]}
# # net_arch default: {"pi": [64, 64], "vf": [64, 64]}
# # activation_fn = nn.Tanh / nn.ReLU
# ```

# %% [markdown]
# # Part III: Automatic Hyperparameter Tuning

# %% [markdown]
# In this part we will create a script that allows to search for the best hyperparameters automatically.

# %% [markdown]
# ### Imports

# %%
import optuna
from optuna.pruners import MedianPruner
from optuna.samplers import TPESampler
from optuna.visualization import plot_optimization_history, plot_param_importances

# %% [markdown]
# ### Config

# %%
N_TRIALS = 100  # Maximum number of trials
N_JOBS = 1 # Number of jobs to run in parallel
N_STARTUP_TRIALS = 5  # Stop random sampling after N_STARTUP_TRIALS
N_EVALUATIONS = 2  # Number of evaluations during the training
N_TIMESTEPS = int(2e4)  # Training budget
EVAL_FREQ = int(N_TIMESTEPS / N_EVALUATIONS)
N_EVAL_ENVS = 5
N_EVAL_EPISODES = 10
TIMEOUT = int(60 * 15)  # 15 minutes

ENV_ID = "CartPole-v1"

DEFAULT_HYPERPARAMS = {
    "policy": "MlpPolicy",
    "env": ENV_ID,
}

# %% [markdown]
# ### Exercise (5 minutes): Define the search space

# %%
from typing import Any, Dict
import torch
import torch.nn as nn

def sample_a2c_params(trial: optuna.Trial) -> Dict[str, Any]:
    """
    Sampler for A2C hyperparameters.

    :param trial: Optuna trial object
    :return: The sampled hyperparameters for the given trial.
    """
    # Discount factor between 0.9 and 0.9999
    gamma = 1.0 - trial.suggest_float("gamma", 0.0001, 0.1, log=True)
    max_grad_norm = trial.suggest_float("max_grad_norm", 0.3, 5.0, log=True)
    # 8, 16, 32, ... 1024
    n_steps = 2 ** trial.suggest_int("exponent_n_steps", 3, 10)

    ### YOUR CODE HERE
    # TODO:
    # - define the learning rate search space [1e-5, 1] (log) -> `suggest_float`
    # - define the network architecture search space ["tiny", "small"] -> `suggest_categorical`
    # - define the activation function search space ["tanh", "relu"]
    learning_rate = trial.suggest_float("lr", 1e-5, 1, log=True)
    net_arch = trial.suggest_categorical("net_arch", ["tiny","small"])
    activation_fn = trial.suggest_categorical("activation_fn", ["tanh","relu"])

    ### END OF YOUR CODE

    # Display true values
    trial.set_user_attr("gamma_", gamma)
    trial.set_user_attr("n_steps", n_steps)

    net_arch = [
        {"pi": [64], "vf": [64]}
        if net_arch == "tiny"
        else {"pi": [64, 64], "vf": [64, 64]}
    ]

    activation_fn = {"tanh": nn.Tanh, "relu": nn.ReLU}[activation_fn]

    return {
        "n_steps": n_steps,
        "gamma": gamma,
        "learning_rate": learning_rate,
        "max_grad_norm": max_grad_norm,
        "policy_kwargs": {
            "net_arch": net_arch,
            "activation_fn": activation_fn,
        },
    }

# %% [markdown]
# ### Define the objective function

# %% [markdown]
# First we define a custom callback to report the results of periodic evaluations to Optuna:

# %%
from stable_baselines3.common.callbacks import EvalCallback

class TrialEvalCallback(EvalCallback):
    """
    Callback used for evaluating and reporting a trial.
    
    :param eval_env: Evaluation environement
    :param trial: Optuna trial object
    :param n_eval_episodes: Number of evaluation episodes
    :param eval_freq:   Evaluate the agent every ``eval_freq`` call of the callback.
    :param deterministic: Whether the evaluation should
        use a stochastic or deterministic policy.
    :param verbose:
    """

    def __init__(
        self,
        eval_env: gym.Env,
        trial: optuna.Trial,
        n_eval_episodes: int = 5,
        eval_freq: int = 10000,
        deterministic: bool = True,
        verbose: int = 0,
    ):

        super().__init__(
            eval_env=eval_env,
            n_eval_episodes=n_eval_episodes,
            eval_freq=eval_freq,
            deterministic=deterministic,
            verbose=verbose,
        )
        self.trial = trial
        self.eval_idx = 0
        self.is_pruned = False

    def _on_step(self) -> bool:
        if self.eval_freq > 0 and self.n_calls % self.eval_freq == 0:
            # Evaluate policy (done in the parent class)
            super()._on_step()
            self.eval_idx += 1
            # Send report to Optuna
            self.trial.report(self.last_mean_reward, self.eval_idx)
            # Prune trial if need
            if self.trial.should_prune():
                self.is_pruned = True
                return False
        return True

# %% [markdown]
# ### Exercise (10 minutes): Define the objective function

# %% [markdown]
# Then we define the objective function that is in charge of sampling hyperparameters, creating the model and then returning the result to Optuna

# %%
def objective(trial: optuna.Trial) -> float:
    """
    Objective function using by Optuna to evaluate
    one configuration (i.e., one set of hyperparameters).

    Given a trial object, it will sample hyperparameters,
    evaluate it and report the result (mean episodic reward after training)

    :param trial: Optuna trial object
    :return: Mean episodic reward after training
    """

    kwargs = DEFAULT_HYPERPARAMS.copy()
    ### YOUR CODE HERE
    # TODO: 
    # 1. Sample hyperparameters and update the default keyword arguments: `kwargs.update(other_params)`
    # 2. Create the evaluation envs
    # 3. Create the `TrialEvalCallback`

    # 1. Sample hyperparameters and update the keyword arguments
    kwargs.update(sample_a2c_params(trial))

    # Create the RL model
    model = A2C(**kwargs)

    # 2. Create envs used for evaluation using `make_vec_env`, `ENV_ID` and `N_EVAL_ENVS`
    eval_envs = make_vec_env(ENV_ID, N_EVAL_ENVS)

    # 3. Create the `TrialEvalCallback` callback defined above that will periodically evaluate
    # and report the performance using `N_EVAL_EPISODES` every `EVAL_FREQ`
    # TrialEvalCallback signature:
    # TrialEvalCallback(eval_env, trial, n_eval_episodes, eval_freq, deterministic, verbose)
    eval_callback = TrialEvalCallback(eval_envs, trial, N_EVAL_EPISODES, EVAL_FREQ, deterministic = True, verbose = False)

    ### END OF YOUR CODE

    nan_encountered = False
    try:
        # Train the model
        model.learn(N_TIMESTEPS, callback=eval_callback)
    except AssertionError as e:
        # Sometimes, random hyperparams can generate NaN
        print(e)
        nan_encountered = True
    finally:
        # Free memory
        model.env.close()
        eval_envs.close()

    # Tell the optimizer that the trial failed
    if nan_encountered:
        return float("nan")

    if eval_callback.is_pruned:
        raise optuna.exceptions.TrialPruned()

    return eval_callback.last_mean_reward

# %% [markdown]
# ### The optimization loop

# %%
import torch as th

# Set pytorch num threads to 1 for faster training
th.set_num_threads(1)
# Select the sampler, can be random, TPESampler, CMAES, ...
sampler = TPESampler(n_startup_trials=N_STARTUP_TRIALS)
# Do not prune before 1/3 of the max budget is used
pruner = MedianPruner(
    n_startup_trials=N_STARTUP_TRIALS, n_warmup_steps=N_EVALUATIONS // 3
)
# Create the study and start the hyperparameter optimization
study = optuna.create_study(sampler=sampler, pruner=pruner, direction="maximize")

try:
    study.optimize(objective, n_trials=N_TRIALS, n_jobs=N_JOBS, timeout=TIMEOUT)
except KeyboardInterrupt:
    pass

print("Number of finished trials: ", len(study.trials))

print("Best trial:")
trial = study.best_trial

print(f"  Value: {trial.value}")

print("  Params: ")
for key, value in trial.params.items():
    print(f"    {key}: {value}")

print("  User attrs:")
for key, value in trial.user_attrs.items():
    print(f"    {key}: {value}")

# Write report
study.trials_dataframe().to_csv("study_results_a2c_cartpole.csv")

fig1 = plot_optimization_history(study)
fig2 = plot_param_importances(study)

fig1.show()
fig2.show()
# Out:
# [I 2023-03-02 02:32:45,596] A new study created in memory with name: no-name-28bde652-6bc3-4213-af82-341f7cd7aa9e
# /usr/local/lib/python3.8/dist-packages/stable_baselines3/common/policies.py:458: UserWarning:
#
# As shared layers in the mlp_extractor are deprecated and will be removed in SB3 v1.8.0, you should now pass directly a dictionary and not a list (net_arch=dict(pi=..., vf=...) instead of net_arch=[dict(pi=..., vf=...)])
#
# [I 2023-03-02 02:33:18,875] Trial 0 finished with value: 111.4 and parameters: {'gamma': 0.0006511863492111116, 'max_grad_norm': 1.5928271449367122, 'exponent_n_steps': 4, 'lr': 3.303894651500485e-05, 'net_arch': 'small', 'activation_fn': 'tanh'}. Best is trial 0 with value: 111.4.
# [I 2023-03-02 02:33:51,590] Trial 1 finished with value: 207.6 and parameters: {'gamma': 0.007904535001366154, 'max_grad_norm': 0.3347560543012135, 'exponent_n_steps': 4, 'lr': 0.0006383713246668049, 'net_arch': 'tiny', 'activation_fn': 'relu'}. Best is trial 1 with value: 207.6.
# [I 2023-03-02 02:34:33,450] Trial 2 finished with value: 122.6 and parameters: {'gamma': 0.004509800453736369, 'max_grad_norm': 2.2843545365743614, 'exponent_n_steps': 3, 'lr': 0.006394713325975255, 'net_arch': 'small', 'activation_fn': 'relu'}. Best is trial 1 with value: 207.6.
# [I 2023-03-02 02:34:59,177] Trial 3 finished with value: 92.0 and parameters: {'gamma': 0.0464657471239018, 'max_grad_norm': 1.960902547575554, 'exponent_n_steps': 10, 'lr': 6.970748381188769e-05, 'net_arch': 'tiny', 'activation_fn': 'relu'}. Best is trial 1 with value: 207.6.
# [I 2023-03-02 02:35:27,029] Trial 4 finished with value: 443.6 and parameters: {'gamma': 0.008848173698484715, 'max_grad_norm': 1.1361590071147536, 'exponent_n_steps': 10, 'lr': 0.006350286984337623, 'net_arch': 'small', 'activation_fn': 'tanh'}. Best is trial 4 with value: 443.6.
# [I 2023-03-02 02:35:40,334] Trial 5 pruned.
# [I 2023-03-02 02:35:53,824] Trial 6 pruned.
# [I 2023-03-02 02:36:07,212] Trial 7 pruned.
# [I 2023-03-02 02:36:33,999] Trial 8 finished with value: 376.2 and parameters: {'gamma': 0.0014154334865770408, 'max_grad_norm': 0.901355284066857, 'exponent_n_steps': 8, 'lr': 0.0009806352176036928, 'net_arch': 'tiny', 'activation_fn': 'tanh'}. Best is trial 4 with value: 443.6.
# [I 2023-03-02 02:36:48,685] Trial 9 pruned.
# [I 2023-03-02 02:37:14,895] Trial 10 finished with value: 232.4 and parameters: {'gamma': 0.0028405987038704426, 'max_grad_norm': 1.2477377748874257, 'exponent_n_steps': 9, 'lr': 0.003687900929556358, 'net_arch': 'tiny', 'activation_fn': 'relu'}. Best is trial 4 with value: 443.6.
# [I 2023-03-02 02:37:41,738] Trial 11 finished with value: 372.8 and parameters: {'gamma': 0.0016142443959160082, 'max_grad_norm': 0.8515128443566826, 'exponent_n_steps': 8, 'lr': 0.0007535324103672578, 'net_arch': 'tiny', 'activation_fn': 'tanh'}. Best is trial 4 with value: 443.6.
# [I 2023-03-02 02:37:54,387] Trial 12 pruned.
# [I 2023-03-02 02:38:08,290] Trial 13 pruned.
# [I 2023-03-02 02:38:20,826] Trial 14 pruned.
# [I 2023-03-02 02:38:34,047] Trial 15 pruned.
# [I 2023-03-02 02:39:02,870] Trial 16 finished with value: 431.8 and parameters: {'gamma': 0.018086656980842095, 'max_grad_norm': 0.9499010747741533, 'exponent_n_steps': 7, 'lr': 0.0014893157946335635, 'net_arch': 'small', 'activation_fn': 'tanh'}. Best is trial 4 with value: 443.6.
# [I 2023-03-02 02:39:34,516] Trial 17 finished with value: 93.2 and parameters: {'gamma': 0.02244980816158846, 'max_grad_norm': 1.5113822324044024, 'exponent_n_steps': 5, 'lr': 0.002014464440193743, 'net_arch': 'small', 'activation_fn': 'tanh'}. Best is trial 4 with value: 443.6.
# [I 2023-03-02 02:40:02,581] Trial 18 finished with value: 148.7 and parameters: {'gamma': 0.04170291824403211, 'max_grad_norm': 0.3114054548437251, 'exponent_n_steps': 7, 'lr': 0.006391334496554562, 'net_arch': 'small', 'activation_fn': 'relu'}. Best is trial 4 with value: 443.6.
# [I 2023-03-02 02:40:15,697] Trial 19 pruned.
# [I 2023-03-02 02:40:30,800] Trial 20 pruned.
# [I 2023-03-02 02:40:56,656] Trial 21 finished with value: 241.2 and parameters: {'gamma': 0.0062502140514708576, 'max_grad_norm': 0.977824519664899, 'exponent_n_steps': 7, 'lr': 0.001077695670886404, 'net_arch': 'tiny', 'activation_fn': 'tanh'}. Best is trial 4 with value: 443.6.
# [I 2023-03-02 02:41:09,754] Trial 22 pruned.
# [I 2023-03-02 02:41:21,894] Trial 23 pruned.
# [I 2023-03-02 02:41:36,180] Trial 24 pruned.
# [I 2023-03-02 02:41:50,440] Trial 25 pruned.
# [I 2023-03-02 02:42:04,533] Trial 26 pruned.
# [I 2023-03-02 02:42:17,682] Trial 27 pruned.
# [I 2023-03-02 02:42:31,658] Trial 28 pruned.
# [I 2023-03-02 02:42:44,801] Trial 29 pruned.
# [I 2023-03-02 02:42:58,315] Trial 30 pruned.
# [I 2023-03-02 02:43:10,896] Trial 31 pruned.
# [I 2023-03-02 02:43:23,089] Trial 32 pruned.
# [I 2023-03-02 02:43:35,997] Trial 33 pruned.
# [I 2023-03-02 02:43:54,444] Trial 34 pruned.
# [I 2023-03-02 02:44:07,429] Trial 35 pruned.
# [I 2023-03-02 02:44:19,831] Trial 36 pruned.
# [I 2023-03-02 02:44:33,181] Trial 37 pruned.
# [I 2023-03-02 02:44:45,993] Trial 38 pruned.
# [I 2023-03-02 02:44:58,923] Trial 39 pruned.
# [I 2023-03-02 02:45:14,089] Trial 40 pruned.
# [I 2023-03-02 02:45:27,463] Trial 41 pruned.
# [I 2023-03-02 02:45:54,399] Trial 42 finished with value: 498.6 and parameters: {'gamma': 0.0061238162535229065, 'max_grad_norm': 0.7867146139747808, 'exponent_n_steps': 7, 'lr': 0.0012421539293228615, 'net_arch': 'tiny', 'activation_fn': 'tanh'}. Best is trial 42 with value: 498.6.
# [I 2023-03-02 02:46:21,329] Trial 43 finished with value: 500.0 and parameters: {'gamma': 0.0029318972471646687, 'max_grad_norm': 0.7666321610476025, 'exponent_n_steps': 6, 'lr': 0.0037188541903579804, 'net_arch': 'tiny', 'activation_fn': 'tanh'}. Best is trial 43 with value: 500.0.
# [I 2023-03-02 02:46:34,696] Trial 44 pruned.
# [I 2023-03-02 02:47:01,652] Trial 45 finished with value: 494.2 and parameters: {'gamma': 0.007670005282322513, 'max_grad_norm': 0.7848865381700457, 'exponent_n_steps': 6, 'lr': 0.0021587141422597725, 'net_arch': 'tiny', 'activation_fn': 'tanh'}. Best is trial 43 with value: 500.0.
# [I 2023-03-02 02:47:29,803] Trial 46 finished with value: 500.0 and parameters: {'gamma': 0.007947101999529764, 'max_grad_norm': 0.6793448555125644, 'exponent_n_steps': 5, 'lr': 0.0022609782781769423, 'net_arch': 'tiny', 'activation_fn': 'tanh'}. Best is trial 43 with value: 500.0.
# [I 2023-03-02 02:47:44,857] Trial 47 pruned.
# [I 2023-03-02 02:48:12,934] Trial 48 finished with value: 86.6 and parameters: {'gamma': 0.006292039703162565, 'max_grad_norm': 0.4844582813446964, 'exponent_n_steps': 5, 'lr': 0.005178370787550786, 'net_arch': 'tiny', 'activation_fn': 'tanh'}. Best is trial 43 with value: 500.0.
# Number of finished trials:  49
# Best trial:
#   Value: 500.0
#   Params:
#     gamma: 0.0029318972471646687
#     max_grad_norm: 0.7666321610476025
#     exponent_n_steps: 6
#     lr: 0.0037188541903579804
#     net_arch: tiny
#     activation_fn: tanh
#   User attrs:
#     gamma_: 0.9970681027528353
#     n_steps: 64
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="ca79a403-bd92-4d63-8e35-11ebce0884cc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ca79a403-bd92-4d63-8e35-11ebce0884cc")) {                    Plotly.newPlot(                        "ca79a403-bd92-4d63-8e35-11ebce0884cc",                        [{"mode":"markers","name":"Objective Value","x":[0,1,2,3,4,8,10,11,16,17,18,21,42,43,45,46,48],"y":[111.4,207.6,122.6,92.0,443.6,376.2,232.4,372.8,431.8,93.2,148.7,241.2,498.6,500.0,494.2,500.0,86.6],"type":"scatter"},{"name":"Best Value","x":[0,1,2,3,4,8,10,11,16,17,18,21,42,43,45,46,48],"y":[111.4,207.6,207.6,207.6,443.6,443.6,443.6,443.6,443.6,443.6,443.6,443.6,498.6,500.0,500.0,500.0,500.0],"type":"scatter"}],                        {"title":{"text":"Optimization History Plot"},"xaxis":{"title":{"text":"Trial"}},"yaxis":{"title":{"text":"Objective Value"}},"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="c06b05b7-09e0-476c-9d23-1054d7adcb7d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c06b05b7-09e0-476c-9d23-1054d7adcb7d")) {                    Plotly.newPlot(                        "c06b05b7-09e0-476c-9d23-1054d7adcb7d",                        [{"cliponaxis":false,"hovertemplate":["lr (FloatDistribution): 0.01700181271224436<extra></extra>","activation_fn (CategoricalDistribution): 0.09742712266438804<extra></extra>","gamma (FloatDistribution): 0.10824041953067476<extra></extra>","exponent_n_steps (IntDistribution): 0.12777550951442354<extra></extra>","net_arch (CategoricalDistribution): 0.14210573158475232<extra></extra>","max_grad_norm (FloatDistribution): 0.507449403993517<extra></extra>"],"marker":{"color":"rgb(66,146,198)"},"orientation":"h","text":["0.02","0.10","0.11","0.13","0.14","0.51"],"textposition":"outside","x":[0.01700181271224436,0.09742712266438804,0.10824041953067476,0.12777550951442354,0.14210573158475232,0.507449403993517],"y":["lr","activation_fn","gamma","exponent_n_steps","net_arch","max_grad_norm"],"type":"bar"}],                        {"showlegend":false,"title":{"text":"Hyperparameter Importances"},"xaxis":{"title":{"text":"Importance for Objective Value"}},"yaxis":{"title":{"text":"Hyperparameter"}},"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"color ...

# %% [markdown]
# Complete example: https://github.com/DLR-RM/rl-baselines3-zoo

# %% [markdown]
# # Conclusion
#
# What we have seen in this notebook:
# - the importance of good hyperparameters
# - how to do automatic hyperparameter search with optuna
